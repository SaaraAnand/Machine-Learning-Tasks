# %%
import csv
a = []
with open('/content/DATASET3.csv', 'r') as csvfile:
    next(csvfile)
    for row in csv.reader(csvfile):
        a.append(row)
    print(a)

print("\nThe total number of training instances are : ",len(a))

num_attribute = len(a[0])-1

print("\nThe initial hypothesis is : ")
hypothesis = ['0']*num_attribute
print(hypothesis)

for i in range(0, len(a)):
    if a[i][num_attribute] == 'yes':
        print ("\nInstance ", i+1, "is", a[i], " and is Positive Instance")
        for j in range(0, num_attribute):
            if hypothesis[j] == '0' or hypothesis[j] == a[i][j]:
                hypothesis[j] = a[i][j]
            else:
                hypothesis[j] = '?'
        print("The hypothesis for the training instance", i+1, " is: " , hypothesis, "\n")

    if a[i][num_attribute] == 'no':
        print ("\nInstance ", i+1, "is", a[i], " and is Negative Instance Hence Ignored")
        print("The hypothesis for the training instance", i+1, " is: " , hypothesis, "\n")

print("\nThe Maximally specific hypothesis for the training instance is ", hypothesis)
# Out:
# [['D1', 'Sunny', 'Hot', 'High', 'Weak', 'No'], ['D2', 'Sunny', 'Hot', 'High', 'Strong', 'No'], ['D3', 'Overcast', 'Hot', 'High', 'Weak', 'Yes'], ['D4', 'Rain', 'Mild', 'High', 'Weak', 'Yes'], ['D5', 'Rain', 'Cool', 'Normal', 'Weak', 'Yes'], ['D6', 'Rain', 'Cool', 'Normal', 'Strong', 'No'], ['D7', 'Overcast', 'Cool', 'Normal', 'Strong', 'Yes'], ['D8', 'Sunny', 'Mild', 'High', 'Weak', 'No'], ['D9', 'Sunny', 'Cool', 'Normal', 'Weak', 'Yes'], ['D10', 'Rain', 'Mild', 'Normal', 'Weak', 'Yes'], ['D11', 'Sunny', 'Mild', 'Normal', 'Strong', 'Yes'], ['D12', 'Overcast', 'Mild', 'High', 'Strong', 'Yes'], ['D13', 'Overcast', 'Hot', 'Normal', 'Weak', 'Yes'], ['D14', 'Rain', 'Mild', 'High', 'Strong', 'No']]
#
# The total number of training instances are :  14
#
# The initial hypothesis is :
# ['0', '0', '0', '0', '0']
#
# The Maximally specific hypothesis for the training instance is  ['0', '0', '0', '0', '0']

# %%
import numpy as np 
import pandas as pd

data = pd.read_csv('/content/DATASET3.csv')
concepts = np.array(data.iloc[:,0:-1])
print("\nInstances are:\n",concepts)
target = np.array(data.iloc[:,-1])
print("\nTarget Values are: ",target)

def learn(concepts, target): 
    specific_h = concepts[0].copy()
    print("\nInitialization of specific_h and genearal_h")
    print("\nSpecific Boundary: ", specific_h)
    general_h = [["?" for i in range(len(specific_h))] for i in range(len(specific_h))]
    print("\nGeneric Boundary: ",general_h)  

    for i, h in enumerate(concepts):
        print("\nInstance", i+1 , "is ", h)
        if target[i] == "yes":
            print("Instance is Positive ")
            for x in range(len(specific_h)): 
                if h[x]!= specific_h[x]:                    
                    specific_h[x] ='?'                     
                    general_h[x][x] ='?'
                   
        if target[i] == "no":            
            print("Instance is Negative ")
            for x in range(len(specific_h)): 
                if h[x]!= specific_h[x]:                    
                    general_h[x][x] = specific_h[x]                
                else:                    
                    general_h[x][x] = '?'        
        
        print("Specific Bundary after ", i+1, "Instance is ", specific_h)         
        print("Generic Boundary after ", i+1, "Instance is ", general_h)
        print("\n")

    indices = [i for i, val in enumerate(general_h) if val == ['?', '?', '?', '?', '?', '?']]    
    for i in indices:   
        general_h.remove(['?', '?', '?', '?', '?', '?']) 
    return specific_h, general_h 

s_final, g_final = learn(concepts, target)

print("Final Specific_h: ", s_final, sep="\n")
print("Final General_h: ", g_final, sep="\n")
# Out:
# Instances are:
#  [['D1' 'Sunny' 'Hot' 'High' 'Weak']
#  ['D2' 'Sunny' 'Hot' 'High' 'Strong']
#  ['D3' 'Overcast' 'Hot' 'High' 'Weak']
#  ['D4' 'Rain' 'Mild' 'High' 'Weak']
#  ['D5' 'Rain' 'Cool' 'Normal' 'Weak']
#  ['D6' 'Rain' 'Cool' 'Normal' 'Strong']
#  ['D7' 'Overcast' 'Cool' 'Normal' 'Strong']
#  ['D8' 'Sunny' 'Mild' 'High' 'Weak']
#  ['D9' 'Sunny' 'Cool' 'Normal' 'Weak']
#  ['D10' 'Rain' 'Mild' 'Normal' 'Weak']
#  ['D11' 'Sunny' 'Mild' 'Normal' 'Strong']
#  ['D12' 'Overcast' 'Mild' 'High' 'Strong']
#  ['D13' 'Overcast' 'Hot' 'Normal' 'Weak']
#  ['D14' 'Rain' 'Mild' 'High' 'Strong']]
#
# Target Values are:  ['No' 'No' 'Yes' 'Yes' 'Yes' 'No' 'Yes' 'No' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes'
#  'No']
#
# Initialization of specific_h and genearal_h
#
# Specific Boundary:  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
#
# Generic Boundary:  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
# Instance 1 is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Specific Bundary after  1 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  1 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 2 is  ['D2' 'Sunny' 'Hot' 'High' 'Strong']
# Specific Bundary after  2 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  2 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 3 is  ['D3' 'Overcast' 'Hot' 'High' 'Weak']
# Specific Bundary after  3 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  3 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 4 is  ['D4' 'Rain' 'Mild' 'High' 'Weak']
# Specific Bundary after  4 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  4 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 5 is  ['D5' 'Rain' 'Cool' 'Normal' 'Weak']
# Specific Bundary after  5 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  5 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 6 is  ['D6' 'Rain' 'Cool' 'Normal' 'Strong']
# Specific Bundary after  6 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  6 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 7 is  ['D7' 'Overcast' 'Cool' 'Normal' 'Strong']
# Specific Bundary after  7 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  7 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 8 is  ['D8' 'Sunny' 'Mild' 'High' 'Weak']
# Specific Bundary after  8 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  8 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 9 is  ['D9' 'Sunny' 'Cool' 'Normal' 'Weak']
# Specific Bundary after  9 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  9 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 10 is  ['D10' 'Rain' 'Mild' 'Normal' 'Weak']
# Specific Bundary after  10 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  10 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 11 is  ['D11' 'Sunny' 'Mild' 'Normal' 'Strong']
# Specific Bundary after  11 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  11 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 12 is  ['D12' 'Overcast' 'Mild' 'High' 'Strong']
# Specific Bundary after  12 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  12 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 13 is  ['D13' 'Overcast' 'Hot' 'Normal' 'Weak']
# Specific Bundary after  13 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  13 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
#
# Instance 14 is  ['D14' 'Rain' 'Mild' 'High' 'Strong']
# Specific Bundary after  14 Instance is  ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Generic Boundary after  14 Instance is  [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
#
#
# Final Specific_h:
# ['D1' 'Sunny' 'Hot' 'High' 'Weak']
# Final General_h:
# [['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?']]
